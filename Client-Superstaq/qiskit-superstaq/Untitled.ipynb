# %%
import qiskit_superstaq as qss
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import qiskit_superstaq as qss
#
# File ~/PavanFiles/SuperMarQ/client-superstaq/qiskit-superstaq/qiskit_superstaq/__init__.py:1
# ----> 1 from . import compiler_output, custom_gates, serialization, validation
#       2 from ._version import __version__
#       3 from .compiler_output import active_qubit_indices, classical_bit_mapping, measured_qubit_indices
#
# File ~/PavanFiles/SuperMarQ/client-superstaq/qiskit-superstaq/qiskit_superstaq/compiler_output.py:10
#       7 from typing import Any
#       9 import general_superstaq as gss
# ---> 10 import qiskit
#      12 import qiskit_superstaq as qss
#      14 try:
#
# File ~/.local/lib/python3.10/site-packages/qiskit/__init__.py:38
#      36     _suppress_error = os.environ.get("QISKIT_SUPPRESS_1_0_IMPORT_ERROR", False) == "1"
# ...

# %%
#!pip install .[dev]
# Out:
# Processing /home/cdac/PavanFiles/SuperMarQ/client-superstaq/qiskit-superstaq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached checks_superstaq-0.5.24-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached qiskit_ibm_provider-0.11.0-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (78 kB)
# ...
#   Using cached flake8-7.1.1-py2.py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached flake8_modern_annotations-1.6.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached flake8_pyproject-1.2.3-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached flake8_type_checking-2.9.1-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached isort-5.13.2-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mypy-1.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (1.9 kB)
# ...
